# %% [markdown]
# # Final Entry for SPWLA PDDA Competition
#
# SedStrat Team (Epo Kusumah, Mohammad Aviandito, Yogi Pamadya) - May 2020
#
# ## Summary
#
# DTC and DTS prediction using triple combo data are still growing until today. Most of the work use either machine learning or deep learning approach. One of the work in this topic is [Machine Learning for Subsurface Characterization (2020)](https://www.sciencedirect.com/book/9780128177365/machine-learning-for-subsurface-characterization) by Siddharth Misra et al. However, we think that there will be always unique features that make each prediction unique, thus we tried to develop our own approach. Our objectives are:
# - Having on-hand experience on doing research in data-driven analysis
# - Exploring and exploiting data, especially DTC and DTS and its relation with conventional Triple Combo log data
# - Trial and error of machine learning algorithms as well as preprocessing methods
#
# As a disclaimer, our final submission is designed to be biased towards the competition’s scoring system. Therefore, the application in different cases will need further adjustment. However, we think that general ideas in feature engineering, treatment of train-validation data, and prediction are quite robust.
#
# ## Model Framework
# Figure below illustrates the modeling framework that we used in the final submission. We did the prediction of DTC and DTS independently from each other.
#
# All the steps we’ve taken were based on countless trial-and-error on various ideas. For example, we have tried removing outliers in train data at train-validation split, using more engineered features in DTC and DTS prediction, using DTC prediction to predict DTS, etc. However, these steps produced the best score in the competition’s leaderboard.
#
# ![Model Framework](images/workflow.png)
#
# ## Feature Engineering
#
# ### Natural Log Transformation
#
# Based on the EDA in original logs, we found that there are some logs that have non-normal distribution. This might decrease the performance of the algorithm in the latter stage. Therefore we decided to do a log transform on all logs, including DTC and DTS.
#
# Figure below shows the on GR logs before (left) and after (right) natural log transformation.
#
# ![GR](images/GR.png)
#
#
# ### New Features
#
# Scikit-learn is an open source package. Any team can run the same algorithm, hence it is easy to achieve similar results. Therefore, we rely on feature engineering to improve the score of our submission. We think that the impact of prediction algorithms used is not as significant as the impact of feature engineering.
#
# We realized that DTC and DTS will behave differently in different lithology, fluid, and borehole condition. Thus we will create discriminant to differ lithology, fluid, and borehole condition. However, after trial and error, we found that lithology feature was one of the most useful for our predictions.
#
# #### Lithology
#
# Our lithology feature were based on the classical NPHI-RHOB crossplot used in conventional petrophysical analysis. We started with points of NPHI-RHOB observations and sandstone, limestone, and dolomite matrix lines. Then, we formulate a simple geometry problem of distance between the observation points and the matrix line. The nearest matrix line from that point will be the lithology of the formation. We then encode the resulting lithology with the standard DTC value of matrix.
#
# ![Lithology](images/lithology.png)
#
# #### Lithology
#
# Bore hole condition sure have direct effect on DTC and DTS values, thus we need to consider actual borehole size (cal). Other than borehole size, we do also extract more information form it, such as Borehole Diameter, mudcake flag, and well collapse flag.
#
# #### Petrophysical Analysis
#
# We also conduct feature engineering for Total Porosity (PHIT), Effective Porosity (PHIE), and water saturation (Sw).
#
# ## Train-validation split
#
# We use 80:20 division between train and validation data. We did not do much at this stage, except for dropping NaNs in train and validation data. This methodology is better than our previous strategy, which involves cleaning data below 1st and 99th percentile (treating them as outliers) in the train data, and do nothing except imputing NaNs with mean in the validation data.
#
# ## Prediction
#
# We did the prediction of DTC and DTS independently for the final submission. This methodology is better than predicting DTC, then use it as a feature to predict DTS that we have tried before.
#
# However, other than that (e.g. selection of algorithms) should be decided on a case-by-case basis. The following algorithm and selection of variables are the ones that produce the best score in the competition’s leaderboard for us. One thing that we noticed is that LightGBM regressor is a well performing algorithm with relatively fast execution speed compared to others.
#
# ### Solution for DTC Prediction
#
# ![DTC](img/dtc_model_2.png)
#
# Algorithm: Two-level stacked model
# * Level 1: predict DTC with a set of engineered features using 8 different algorithms
# * Level 2: use DTC from different model to predict the final DTC
#
# List of features for the first level:
# * ZDEN_log,
# * CNC_log,
# * CAL_log,
# * HRD_log,
# * HRM_log,
# * GR_log,
# * PE_log,
# * encoded lithology,
# * PHIT,
# * PHIE,
# * Sw
#
# ### Solution for DTS Prediction
#
# ![DTS](img/dts_model_2.png)
#
# Algorithm: LightGBM
#
# List of features:
# * ZDEN_log,
# * CNC_log,
# * CAL_log,
# * HRD_log,
# * HRM_log,
# * GR_log,
# * PE_log,
# * encoded lithology

# %% [markdown]
# # Outline <a class="anchor" id="outline"></a>
#
#
# - [1 Exploratory Data Analysis](#1)
# 	- [1.1 Data Condition](#1.1)
# 	- [1.2 Comment on the Raw Data](#1.2)
#
# - [2 1st Group Feature Engineering: Lithology - fluid Identification, log_scale data conversion ](#2)
#     - [2.1 Data Preprocessing Functions](#2.1)
#     - [2.2 Data Preprocessing Review](#2.2)
#     - [2.3 Train Val Splitting](#2.3)
#     - [2.4 1st run on DTC DTS Prediction](#2.4)
#     - [2.5 Tuning on Algorithm Splitting between DTC and DTS ](#2.5)
#     - [2.6 Tuning on Algorithm Splitting between DTC and DTS, with Engineered Features](#2.6)
#
# - [3 2nd Group Feature Engineering: Petrophysical Analysis](#3)
# 	- [3.1 Petrophysical Parameter Picking](#3.1)
# 	- [3.2 Train Val Splitting](#3.2)
# 	- [3.2 Running With Petrophysical Analysis as Features](#3.3)
#
# - [4 Model Stacking](#4)
# 	- [4.1 Model Stacking Trainig with 1st group of Engineered Feature](#4.1)
# 	- [4.2 Model Stacking Trainig with 2nd group of Engineered Feature](#4.2)
#
# - [5. Model Selection](#5)

# %%
import os

import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, LabelEncoder, Normalizer
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

import xgboost
import lightgbm as lgb

import pickle

# %% [markdown]
# # 1 Exploratory Data Analysis <a class="anchor" id="1"></a>

# %% [markdown]
# # 1.1 Data Condition <a class="anchor" id="1.1"></a>
# [back](#outline)<br>
# Two files has been provided to the team, which are:
# - `train.csv` as training dataset
# - `test.csv` as prediction dataset
#
# the logs that provided on `train.csv` and `real_result_20perc.csv` are:
#
# - `['CAL', 'CNC', 'GR', 'HRD', 'HRM', 'PE', 'ZDEN', 'DTC', 'DTS']`
#
# while for test.csv are:
# - `['CAL', 'CNC', 'GR', 'HRD', 'HRM', 'PE', 'ZDEN']`

# %%
'''Data Loading'''
train_well = pd.read_csv(r"D:\EPO\DTCDTS\Data3_1_2020\train.csv").replace(-999.0000, np.nan)
test_well = pd.read_csv(r"D:\EPO\DTCDTS\Data3_1_2020\test.csv").replace(-999.0000, np.nan)

# %%
def grid_plot(col):
    comb = []
    for i in col:
        for j in col:
            comb.append([i,j])

    a,b = len(col), len(col)

    plt.figure(figsize=(5*len(col),5*len(col)))

    for i in range(len(comb)):
        plt.subplot(a,b,i+1)

        plt.xlabel(comb[i][1])
        plt.ylabel(comb[i][0])

        plt.scatter(comb[i][1],comb[i][0], data=train_well, color='red', alpha = 0.1, label='Train Well')

#         plt.legend(loc='upper right')
def grid_dtc_dts(col=['GR', 'CNC', 'ZDEN', 'HRD', 'PE', 'CAL']):
    plt.figure(figsize=(25,10))
    
    for i in range(6):
        plt.subplot(2,6,i+1)
        plt.scatter('DTC', col[i], data=train_well, color='red', alpha = 0.1)
        plt.xlabel('DTC')
        plt.ylabel(col[i])
        
    for i in range(6):
        plt.subplot(2,6,i+7)
        plt.scatter('DTS', col[i], data=train_well, color='red', alpha = 0.1)
        plt.xlabel('DTS')
        plt.ylabel(col[i])
        
def triple_combo(data):
    plt.figure(figsize=(25,25))
    plt.title('TRIPLE COMBO PLOT')

    y_temp = range(data.shape[0])
    
    log = ['CAL','GR', 'CNC', 'ZDEN', 'PE', 'HRD','DTC']
    scale = [[0,35],[0, 250], [-0.15, 0.45], [1.95, 2.95], [0,15], [0.2, 2000], [30,330]]
    
    for i in range(len(log)):
        plt.subplot(171+i)
        plt.plot(log[i], y_temp, data=data)
        plt.xlim(scale[i])
        plt.ylim([0,33000])
        if log[i] == 'DTC':
            plt.plot('DTS', y_temp, data=data, c='red', label='DTC')
            
        elif log[i] == 'HRD':
            plt.plot('HRM', y_temp, data=data, c='red', label='HRM')
            plt.gca().set_xscale('log')

            
        elif log[i] == 'CNC':
            plt.gca().invert_xaxis()
            
        plt.gca().invert_yaxis()
        plt.title(log[i])
        
        
def plot_hist_all(log=False):
    plt.figure(figsize=(15,10))
    
    if log == False:
        for i,j in enumerate(['CNC','ZDEN','GR','HRD','DTC','DTS']):
            plt.subplot(3,3,i+1)
            min_dat = int(np.floor(np.nanpercentile(train_well[j], 3)))
            max_dat = int(np.ceil(np.nanpercentile(train_well[j], 97)))

            plt.hist(j, data=train_well, bins= np.linspace(min_dat, max_dat, 40));
            plt.title(j+ ' Histogram')
    else:
        for i,j in enumerate(['CNC_log','ZDEN_log','GR_log','HRD_log','DTC_log','DTS_log']):
            plt.subplot(3,3,i+1)
            min_dat = int(np.floor(np.nanpercentile(train_well[j], 3)))
            max_dat = int(np.ceil(np.nanpercentile(train_well[j], 97)))

            plt.hist(j, data=train_well, bins= np.linspace(min_dat, max_dat, 40));
            plt.title(j+ ' Histogram')

# %% [markdown]
# ### Triple Comb log review

# %%
triple_combo(train_well)

# %% [markdown]
# ### Gridplot Review

# %%
grid_plot(['GR', 'CNC', 'ZDEN', 'HRD', 'PE'])

# %% [markdown]
# ### DTC - DTS Corellation with other Log

# %%
grid_dtc_dts()

# %%
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.scatter('DTC', 'CNC', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTC')
plt.ylabel('CNC')
plt.axis([40,200, 0,1])

plt.subplot(122)
plt.scatter('DTS', 'CNC', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTS')
plt.ylabel('CNC')
plt.axis([40,500, 0,1])

cbar = plt.colorbar()
cbar.set_label('GR')

# %%
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.scatter('DTC', 'ZDEN', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTC')
plt.ylabel('ZDEN')
plt.axis([40,200, 2,3])

plt.subplot(122)
plt.scatter('DTS', 'ZDEN', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTS')
plt.ylabel('ZDEN')
plt.axis([40,500, 2,3])

cbar = plt.colorbar()
cbar.set_label('GR')

# %% [markdown]
# ### Neutron Density Plot Review

# %%
plt.figure(figsize=(9,5))
plt.title('CNC - ZDEN Plot. Figuring out Anomaly PE')
plt.scatter('CNC', 'ZDEN', data=train_well, alpha=0.2, 
            linewidths=None, label = 'Normal',
           c='GR', vmin = 0, vmax= 150)

plt.plot([0, 1],[2.71, 1], '--', color='teal', alpha =0.8, label = 'Limestone Line')
plt.plot([-0.05, 1],[2.65, 1], '--', color='orange', alpha =0.8, label = 'Sandstone Line')
plt.plot([0.05, 1],[2.87, 1], '--', color='purple', alpha =0.8, label = 'Dolomite Line')

plt.ylabel('ZDEN')
plt.xlabel('CNC')

plt.axis([-0.15,0.45,2,2.75])
plt.gca().invert_yaxis()
plt.legend()
plt.colorbar()

# %% [markdown]
# ### Histogram Shape

# %%
plot_hist_all()

# %% [markdown]
# ### Missing Data Review

# %%
plt.imshow(train_well.isna(), aspect='auto')
plt.xticks(range(len(train_well.columns)), train_well.columns, rotation='vertical');

# %%
train_well.isna().sum()
# Out:
# CAL      510
# CNC      735
# GR       254
# HRD      385
# HRM      385
# PE       679
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64

# %% [markdown]
# ### Absolute Corellation plot against Conventional Log

# %%
plt.figure(figsize=(12,8))
plt.subplot(211)
plt.bar(train_well.corr()['DTC'].index[:-2], np.absolute(train_well.corr()['DTC'].values)[:-2])

plt.subplot(212)
plt.bar(train_well.corr()['DTS'].index[:-2], np.absolute(train_well.corr()['DTS'].values)[:-2])
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ## 1.2 Comment on the Raw Data <a class="anchor" id="1.2">
# </a>
#
# [back](#outline)<br>
#
# **Triple Combo plot observation**
# - on tripple combo log, `PE` showoing value anomaly at depth index > 20000. Regardless anomaly value in PE,  `CNC` vs `ZDEN` did not showing any peculiar distribution. However, ND Plot this error occured only in `PE` log, `CNC` and `ZDEN` are still useable on where `PE` log showing peculiar value.
# - Borehole condition is very bad, there are many caving and mudcake anywhere in the data.
#
#
# **Grid plot observation**
#
# - Gridplot showing that most of the log in `train_well` consist Outliers. Those outliers could be occured due to log reading error. It might not represent true physical property of the formation, for example the `CNC` vs `ZDEN` plot, `CNC` (Neutron Por) have *value more than 1*, and `ZDEN` (Density) have *negative values*.
# - Some data preprocessing is required to decimate data error
#
#
# **ND plot observation**
# - We reckon there are at leaast three lithology identified in this log file. Sandstone, Limestone, Dolomite, and Shale. No Coal and Evaporite identified on this log file.
#
# **Histogram plot observation**
# - Most of the histogram showing skewed normal distribution. We suggest to apply 'log scale transformation' to main features
#
# **Missing Data observation**
# - There are many missing data in this. In the row where any missing value present will be dropped.
# - `DTC` and `DTS` has the most missing value.
#
#
# **Corr plot observation**
# - According to corr plot, ZDEN and CAL have strongest correlation amongst
# - Corr values:
#     - ZDEN    0.731694
#     - CAL     0.585637
#     - PE      0.477204
#     - HRD     0.426659
#     - GR      0.355556
#     - CNC     0.008636
#     - HRM     0.002028
# - Regadless its correlation property, we will conduct trial and error with different combinations of log to achieve the best result.

# %% [markdown]
# # 2 1st Group Feature Engineering: Lithology -  fluid Identification, log_scale data conversion <a class="anchor" id="2"></a>
#
# [back](#outline)<br>
# Feature engineering means to generate more data that hopefully reduce error in predicting DTC DTS. The feature engineering that we will do:
# - Calculating simple Density Porosity (dphi) - (float)
# - Water interval flag - (bool)
# - HC interval flag - (bool)
# - Fluid indicator - (str) / (int)
# - Hole Qc flag (bool)
# - Borehole size - (float)
# - Lithology Indicator - (str)
# - Deep Res / Shallow Res Flag - (str)
# - Normalized Difference Gamma Ray - (float)

# %% [markdown]
# ## 2.1 Data Preprocessing Functions <a class="anchor" id="2.1"></a>
#
# [back](#outline)<br>

# %%
# Feature engineering functions

def dphi(RHOB, rhoma = 2.65, rhofl = 1.1):
    if math.isnan(RHOB):
        return np.nan
    else:
        phi = (rhoma - RHOB) / (rhoma - rhofl)
        return phi

def water_lst_flag(phi_diff_lst, threshold = 0.015):
    if math.isnan(phi_diff_lst):
        return np.nan
    else:
        if phi_diff_lst < threshold:
            return 1
        else: 
            return 0
        
def hc_ind_flag(phi_diff_lst, threshold = 0.3):
    if math.isnan(phi_diff_lst):
        return np.nan
    else:
        if phi_diff_lst > threshold:
            return 1
        else: 
            return 0
        
def fluid_indicator(phi_diff_lst, threshold = 0.3):
    if math.isnan(phi_diff_lst):
        return np.nan
    else:
        if phi_diff_lst > threshold:
            return 'HC'
        else: 
            return 'Water'
        
    
def borehole_size(cal):
    dist_to_1225 = abs(cal - 12.25) # can be written using zip
    dist_to_85 = abs(cal - 8.5)
    dist_to_6 = abs(cal - 6)
    
    if (dist_to_1225 < dist_to_85) and (dist_to_1225 < dist_to_6):
        return 12.25
    elif (dist_to_85 < dist_to_1225) and (dist_to_85 < dist_to_6):
        return 8.5
    elif (dist_to_6 < dist_to_1225) and (dist_to_6 < dist_to_85):
        return 6
    else:
        return np.nan
    
def hole_qc_flag(hole_diff):
    if hole_diff > 0:
        return 'Washout'
    elif hole_diff <= 0: 
        return 'Mudcake'
    else:
        return np.nan
    
def dist_2d(line_start, line_end, point):
    """
    Determine distance between a point to a line marked by starting point and ending point
    Used in litho_chart() function
    """
    line_start = np.asarray(line_start)
    line_end = np.asarray(line_end)
    point = np.asarray(point)
    
    d = linalg.norm(np.cross(line_end-line_start, line_start-point))/linalg.norm(line_end-line_start)
    return d

def litho_chart(NPHI, RHOB, GR, p90):
    """
    Determine a (NPHI, RHOB) point distance towards a CP-1b matrix line
    Return the lithology based on the shortest distance
    Crossplot ref: https://wiki.aapg.org/File:Predicting-reservoir-system-quality-and-performance_fig9-31.png
    Matrix DTC ref:
    - Reservoir:
    https://www.uio.no/studier/emner/matnat/geofag/GEO4250/v08/undervisningsmateriale/Lectures/BWLA%20-%20Porosity%20Logs.pdf 
    using us/ft
    - Shale: https://www.spec2000.net/13-lithdn.htm using us/ft in kaolinite
    
    TODO: 
    - use equation instead of 2 lines (to capture dolomite nonlinearity). 
    - add more lithology line
    - automate the percentile calculation
    """
    if math.isnan(NPHI) or math.isnan(RHOB) or math.isnan(GR):
        return np.nan
    elif GR >= p90:
        return 'Shale'
    else:
        sst_line_start = (-0.02, 2.65)
        sst_line_end = (0.35, 2)

        lst_line_start = (0, 2.71)
        lst_line_end = (0.4, 2)

        dol_line_start = (0.02, 2.87)
        dol_line_end = (0.43, 2.14)

        dist_to_sst = dist_2d(sst_line_start, sst_line_end, (NPHI, RHOB))
        dist_to_lst = dist_2d(lst_line_start, lst_line_end, (NPHI, RHOB))
        dist_to_dol = dist_2d(dol_line_start, dol_line_end, (NPHI, RHOB))
        
        if dist_to_sst < dist_to_lst and dist_to_sst < dist_to_dol:
#             return 182
#             return 55.5
            return 'Sandstone'
        elif dist_to_lst < dist_to_sst and dist_to_lst < dist_to_dol:
#             return 155
#             return 47.5
            return 'Limestone'
        elif dist_to_dol < dist_to_sst and dist_to_dol < dist_to_lst:
#             return 144
#             return 43.5
            return 'Dolomite'
        else:
            return np.nan

def deep_res_check(deep_res, mid_res):
    if math.isnan(deep_res) or math.isnan(mid_res):
        return np.nan
    else:
        if np.log10(deep_res) > 3 * np.log10(mid_res):
            return 1
        else:
            return 0
    
# Define error measure for official scoring : RMSE
def rmse_cv(model, x, y):
    scorer = make_scorer(mean_squared_error, greater_is_better = False)
    rmse= np.sqrt(-cross_val_score(model, x, y, scoring = scorer, cv = 10))
    return(rmse)

def rolling_NDI(df, curve, window = 500, perc_min = 0.03, perc_max = 0.97):
    """
    Auto VShale calculator with rolling window.
    """
    log = df[curve]
    length = len(log)
    NDI = []
    for index, reading in enumerate(log):
        if (index > window) & (index < length - window):
            
            perc_interval = log[index - window : index + window]
            
            grma = np.quantile(perc_interval, perc_min)
            grsh = np.quantile(perc_interval, perc_max)
            
            NDI.append((reading - grma) / (grsh - grma))
            
        elif (index<window):
            perc_interval = log[0 : index + window]
            
            grma = np.quantile(perc_interval, perc_min)
            grsh = np.quantile(perc_interval, perc_max)
            
            NDI.append((reading - grma) / (grsh - grma))
        
        elif (index>window):
            perc_interval = log[index - window : length]
            
            grma = np.quantile(perc_interval, perc_min)
            grsh = np.quantile(perc_interval, perc_max)
            
            NDI.append((reading - grma) / (grsh - grma))
            
        else:
            NDI.append(np.nan)
    
    df[curve + '_NDI'] = NDI
    
    return df

# well data prep wrapper function
def prepare_well(loaded_well):
    # feature engineering
    loaded_well['borehole_sz'] = loaded_well.apply(lambda df: borehole_size(df.CAL), axis = 1)
    loaded_well['hole_diff'] = loaded_well['CAL'] - loaded_well['borehole_sz']
    loaded_well['hole_qc'] = loaded_well.apply(lambda df: hole_qc_flag(df.hole_diff), axis = 1)
    loaded_well['phid_lst'] = loaded_well.apply(lambda df: dphi(df.ZDEN, rhoma = 2.71), axis = 1)
    loaded_well['phi_diff_lst'] = abs(loaded_well['CNC'] - loaded_well['phid_lst'])
    loaded_well['is_water_lst'] = loaded_well.apply(lambda df: water_lst_flag(df.phi_diff_lst), axis = 1)
    loaded_well['fluid'] = loaded_well.apply(lambda df:fluid_indicator(df.phi_diff_lst, threshold = 0.3), axis = 1)

    loaded_well['is_hc_ind'] = loaded_well.apply(lambda df: hc_ind_flag(df.phi_diff_lst), axis = 1)
    loaded_well['is_deep_res_higher'] = loaded_well.apply(lambda df: deep_res_check(deep_res = df.HRD, mid_res = df.HRM), axis = 1)
    loaded_well['lithology'] = loaded_well.apply(lambda df: litho_chart(NPHI = df.CNC, RHOB = df.ZDEN, GR = df.GR, p90 = 90), axis = 1)
    
    # categorical data encoding
    litho_dict = {'Shale' : 211,
                 'Sandstone' : 182,
                 'Limestone' : 153,
                 'Dolomite' : 144}
    loaded_well['litho_ord'] = loaded_well.lithology.map(litho_dict)

    hole_qc_dict = {'Washout' : 1, 
                    'Mudcake' : 2} 
    loaded_well['hole_qc_ord'] = loaded_well.hole_qc.map(hole_qc_dict)
    
    # log transform
    log_trf = ['CAL', 'CNC', 'GR', 'HRD', 'HRM', 'PE', 
               'ZDEN', 'borehole_sz', 'hole_diff', 'phid_lst', 
               'phi_diff_lst', 'litho_ord', 'hole_qc_ord']
    
    loaded_well = rolling_NDI(loaded_well, curve= 'GR', 
                         window=250, 
                         perc_max=0.97, 
                         perc_min=0.03)
    

    for log in log_trf:
        loaded_well[log + '_log'] = np.log1p(loaded_well[log])
    
    
    
    return loaded_well

# %%
train_well = prepare_well(pd.read_csv(r"Data3_1_2020\train.csv").replace(-999.0000, np.nan)).dropna()
train_well['DTC_log'] = np.log1p(train_well['DTC'])
train_well['DTS_log'] = np.log1p(train_well['DTS'])

test_well = prepare_well(pd.read_csv(r"Data3_1_2020\test.csv").replace(-999.0000, np.nan))
# Out:
# c:\users\user\miniconda3\envs\learning\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## 2.2 Data Preprocessing Review <a class="anchor" id="2.2"></a>
#
# [back](#outline)<br>

# %%
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.scatter('DTC_log', 'CNC_log', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTC_log')
plt.ylabel('CNC_log')
plt.axis([4,5, 0,1])

plt.subplot(122)
plt.scatter('DTS_log', 'CNC_log', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTS_log')
plt.ylabel('CNC_log')
plt.axis([4,6.5, 0,1])

cbar = plt.colorbar()
cbar.set_label('GR')

# %%
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.scatter('DTC_log', 'ZDEN_log', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTC_log')
plt.ylabel('ZDEN_log')
plt.axis([4,5, 1,1.4])

plt.subplot(122)
plt.scatter('DTS_log', 'ZDEN_log', data=train_well, alpha=0.1,
           c = 'GR', vmin = 0, vmax= 150)
plt.xlabel('DTS_log')
plt.ylabel('ZDEN_log')
plt.axis([4,6.5, 1,1.4])

cbar = plt.colorbar()
cbar.set_label('GR')

# %%
color = ['violet', 'teal', 'orange', 'green']
for i,j in enumerate(train_well.lithology.unique()):
    temp = train_well[train_well.lithology == j]
    plt.scatter('CNC', 'ZDEN', data = temp, alpha = 0.05, 
                label = j, c = color[i])
    

    
plt.plot([0, 1],[2.71, 1], '--', color='blue', alpha =0.8, label = 'Limestone Line')
plt.plot([-0.05, 1],[2.65, 1], '--', color='red', alpha =0.8, label = 'Sandstone Line')
plt.plot([0.05, 1],[2.87, 1], '--', color='purple', alpha =0.8, label = 'Dolomite Line')

plt.ylabel('ZDEN')
plt.xlabel('CNC')

plt.axis([0,0.45,3,2])
plt.legend()

# %%
color = ['violet', 'teal', 'orange', 'green']
plt.figure(figsize=(12,4))
plt.subplot(121)
for i,j in enumerate(train_well.lithology.unique()):
    temp = train_well[train_well.lithology == j]
    plt.scatter('DTC', 'ZDEN', data = temp, alpha = 0.05, 
                label = j, c = color[i])

    
plt.axis([40,160, 1.8, 3])

plt.xlabel('DTC')
plt.ylabel('ZDEN')

plt.subplot(122)
for i,j in enumerate(train_well.lithology.unique()):
    temp = train_well[train_well.lithology == j]
    plt.scatter('DTS', 'ZDEN', data = temp, alpha = 0.05, 
                label = j, c = color[i])

plt.axis([80,500, 1.8, 3])

plt.xlabel('DTS')
plt.ylabel('ZDEN')
    
plt.legend()

# %%
plot_hist_all(log=True)

# %% [markdown]
# ### Comment on Procesed Data
# - With log transformation, DTC - [ZDEN, NPHI, HRD] become more linear
# - With log transformation, histogram looks more 'normal'
# - Lithology have strong control on DTC and DTS value

# %% [markdown]
# ## 2.3 Train Val Splitting <a class="anchor" id="2.3"></a>
#
# [back](#outline)<br>

# %%
X_train, X_val, y_train, y_val = train_test_split(train_well.dropna().drop(['DTC', 'DTS', 'DTC_log', 'DTS_log'], axis = 1), 
                                                  train_well.dropna()[['DTC', 'DTS', 'DTC_log', 'DTS_log']], 
                                                  test_size = 0.2, 
                                                  random_state = 123)

# %% [markdown]
# ## 2.4 1st run on DTC DTS Prediction <a class="anchor" id="2.4"></a>
#
# [back](#outline)<br>

# %%
'''General Training and Scoring Function'''

def train_it(model_dtc, model_dts, X_train,  y_train, plot = False):
    
#     X_train = pd.get_dummies(X_train)
    try:
         model_dtc.fit(X_train, y_train['DTC_log'], verbose=0)
    except:
         model_dtc.fit(X_train, y_train['DTC_log'])
            
    cols = list(X_train.columns)
    
    
    '''==========MODELLING DTC'''
    
    print('DTC ==== on log scale')
    print("RMSE on Training set:", np.sqrt(mean_squared_error((model_dtc.predict(X_train[cols])), 
                                                              y_train['DTC_log'])),'\n',
          "RMSE on test set:", np.sqrt(mean_squared_error((model_dtc.predict(X_val[cols])), 
                                                          y_val['DTC_log'])))
  
    
    dtc_score_train = np.sqrt(mean_squared_error(np.expm1(model_dtc.predict(X_train[cols])), 
                                                 y_train['DTC']))
    dtc_score_val =   np.sqrt(mean_squared_error(np.expm1(model_dtc.predict(X_val  [cols])), 
                                                 y_val  ['DTC']))
    
    print('DTC ==== on normal scale')
    print("RMSE on Training set:", dtc_score_train ,'\n',
          "RMSE on test set:", dtc_score_val ,'\n',
         )
    
    if plot==True:
        plt.figure(figsize=(10,5))

        plt.subplot(1,2,1)
        plt.title('DTC Pred')
        plt.xlabel('pred DTC')
        plt.ylabel('true DTC')
        plt.scatter(np.expm1(model_dtc.predict(X_train[cols])), y_train['DTC'], 
                    c='red', linewidths= 0,alpha = 0.005, label = 'Train Predict')
        plt.scatter(np.expm1(model_dtc.predict(X_val[cols])), y_val['DTC'], 
                    c='blue', linewidths= 0,alpha = 0.005, label = 'Val Predict')

        plt.plot([40, 140],[40, 140], c='black')
        plt.axis([40, 140, 40, 140])
    else:
        pass
    
    
    out_model_dtc = model_dtc

    
    '''==========MODELLING DTS'''
    
    try:
        model_dts.fit(X_train, y_train['DTS_log'], verbose=0)
    except:
        model_dts.fit(X_train, y_train['DTS_log'])
        
    
    print('DTS ==== on log scale')
    print("RMSE on Training set:", np.sqrt(mean_squared_error((model_dts.predict(X_train[cols])), y_train['DTS_log'])),'\n',
          "RMSE on test set:", np.sqrt(mean_squared_error((model_dts.predict(X_val[cols])), y_val['DTS_log'])),'\n',

         )
    
    dts_score_train = np.sqrt(mean_squared_error(np.expm1(model_dts.predict(X_train[cols])), y_train['DTS']))
    dts_score_val = np.sqrt(mean_squared_error(np.expm1(model_dts.predict(X_val[cols])), y_val['DTS']))

    
    print('DTS ==== on normal scale')
    print("RMSE on Training set:", dts_score_train,'\n',
          "RMSE on test set:", dts_score_val,'\n',
         )
    
    
    if plot==True:

        plt.subplot(1,2,2)
        plt.title('DTS Pred')
        plt.xlabel('pred DTS')
        plt.ylabel('true DTS')
        plt.scatter(np.expm1(model_dts.predict(X_train[cols])), y_train['DTS'],
                    c='red', linewidths= 0,alpha = 0.005, label = 'Train Predict')

        plt.scatter(np.expm1(model_dts.predict(X_val[cols])), y_val['DTS'],
                    c='blue', linewidths= 0,alpha = 0.005, label = 'Val Predict')
        plt.plot([50, 350],[50, 350], c='black')
        plt.axis([50,350,50,350])
    else:
        pass

    
    out_model_dts = model_dts

    return [dtc_score_train, dtc_score_val], [dts_score_train, dts_score_val], out_model_dtc, out_model_dts, cols

# %%
'''Helper for Scoring Function'''

def score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment=''):
    global score_summary    

        
    if str(type(dtc_model)) == "<class 'sklearn.pipeline.Pipeline'>":
        temp_dtc = str(dtc_model.steps)
        
    elif str(type(dtc_model)) == 'sklearn.model_selection._search.GridSearchCV':
        temp_dtc = str(dtc_model.best_estimator_.steps)
        
    else:
        temp_dtc = str(dtc_model)
        
        
        
    if str(type(dts_model)) == "<class 'sklearn.pipeline.Pipeline'>":
        temp_dts = str(dts_model.steps)
        
    elif str(type(dts_model)) == 'sklearn.model_selection._search.GridSearchCV':
        temp_dtc = str(dtc_model.best_estimator_.steps)
    else:
        temp_dts = str(dts_model)


    temp = {'training_features':[col],
            
            'dtc_model':str(temp_dtc),
            'dtc_train_score':dtc_score[0],
            'dtc_val_score':dtc_score[1],
            
            'dts_model':str(temp_dts),
            'dts_train_score':dts_score[0],
            'dts_val_score':dts_score[1],
            'comment': comment
           }
    score_summary = score_summary.append(pd.DataFrame(temp), ignore_index = True)
    score_summary = score_summary.drop_duplicates(subset=['dtc_model', 'dts_model', 'dtc_train_score','dts_train_score'])

# %%
'''Scoring Matrix for Every Model Tried'''
score_summary = pd.DataFrame(columns=['training_features',
                                      'dtc_model','dtc_train_score','dtc_val_score',
                                      'dts_model','dts_train_score','dts_val_score',
                                      'comment'])

# %% [markdown]
# ### Running Base Model Results

# %%
'''Reg Var being used to control which Featrures Should be used for Training'''
reg_var = ['ZDEN_log', 
           'CNC_log', 
           'CAL_log', 
           'HRD_log', 
           'HRM_log', 
           'GR_log', 
           'PE_log', 
           'borehole_sz_log', 
           'hole_diff_log', 
           'phid_lst_log', 
           'phi_diff_lst_log', 
           'hole_qc_ord_log',
           'is_deep_res_higher',]

# %%
lr = LinearRegression()

dtc_score, dts_score, dtc_model, dts_model, col = train_it(lr,lr, X_train[reg_var], y_train, plot=True)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: LR')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.05684750782456729
#  RMSE on test set: 0.059219123469419356
# DTC ==== on normal scale
# RMSE on Training set: 5.845265536083821
#  RMSE on test set: 6.588545508932654
#
# DTS ==== on log scale
# RMSE on Training set: 0.09156492572383546
#  RMSE on test set: 0.09441882278624969
#
# DTS ==== on normal scale
# RMSE on Training set: 23.244365866142687
#  RMSE on test set: 26.165789601318412

# %%
'''Add Polynomial Features using Pipeline'''

lasso = Lasso()

dtc_score, dts_score, dtc_model, dts_model, col = train_it(lasso,lasso, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: Lasso')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.23793225061649909
#  RMSE on test set: 0.23859111474237676
# DTC ==== on normal scale
# RMSE on Training set: 22.336683021980644
#  RMSE on test set: 22.568471443603386
#
# DTS ==== on log scale
# RMSE on Training set: 0.35879980602728617
#  RMSE on test set: 0.36314012909858395
#
# DTS ==== on normal scale
# RMSE on Training set: 81.00695135257233
#  RMSE on test set: 82.5514597874997

# %%
'''Add Polynomial Features using Pipeline'''

ridge = Ridge()

dtc_score, dts_score, dtc_model, dts_model, col = train_it(ridge,ridge, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: Ridge')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.05696176946885339
#  RMSE on test set: 0.05910042898162775
# DTC ==== on normal scale
# RMSE on Training set: 5.860480987789168
#  RMSE on test set: 6.539596916506017
#
# DTS ==== on log scale
# RMSE on Training set: 0.09162256659168858
#  RMSE on test set: 0.09433357055050745
#
# DTS ==== on normal scale
# RMSE on Training set: 23.204086317288763
#  RMSE on test set: 25.958789604603886

# %%
RF = RandomForestRegressor()
poly = PolynomialFeatures(degree=2)
RF = Pipeline([('poly', poly),('model',RF)])

dtc_score, dts_score, dtc_model, dts_model, col = train_it(RF,RF, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: RF')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.011232186728833948
#  RMSE on test set: 0.030067393061857392
# DTC ==== on normal scale
# RMSE on Training set: 1.0220262390459265
#  RMSE on test set: 2.705084656694675
#
# DTS ==== on log scale
# RMSE on Training set: 0.014519271064313796
#  RMSE on test set: 0.03978112666945199
#
# DTS ==== on normal scale
# RMSE on Training set: 2.745265519824452
#  RMSE on test set: 7.433530910455878

# %%
ET = ExtraTreesRegressor()
poly = PolynomialFeatures(degree=2)
ET = Pipeline([('poly', poly),('model',ET)])

dtc_score, dts_score, dtc_model, dts_model, col = train_it(ET,ET, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: ExtraTree')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 4.38660256502692e-05
#  RMSE on test set: 0.026534820396965628
# DTC ==== on normal scale
# RMSE on Training set: 0.004025108675325385
#  RMSE on test set: 2.3808505492432257
#
# DTS ==== on log scale
# RMSE on Training set: 4.377771313870686e-05
#  RMSE on test set: 0.03504190364540417
#
# DTS ==== on normal scale
# RMSE on Training set: 0.007994238859396686
#  RMSE on test set: 6.802759311667903

# %%
ADA = AdaBoostRegressor()
poly = PolynomialFeatures(degree=2)
ADA = Pipeline([('poly', poly),('model',ADA)])

dtc_score, dts_score, dtc_model, dts_model, col = train_it(ADA,ADA, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: ADA')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.052321025065183734
#  RMSE on test set: 0.05427087083432408
# DTC ==== on normal scale
# RMSE on Training set: 4.806791152633842
#  RMSE on test set: 5.041001718403275
#
# DTS ==== on log scale
# RMSE on Training set: 0.0714794258411102
#  RMSE on test set: 0.07334144627704778
#
# DTS ==== on normal scale
# RMSE on Training set: 12.87457415157246
#  RMSE on test set: 13.38008498554315

# %%
XGB = xgboost.XGBRegressor()
poly = PolynomialFeatures(degree=2)
XGB = Pipeline([('poly', poly),('model',XGB)])

dtc_score, dts_score, dtc_model, dts_model, col = train_it(XGB,XGB, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: XGBR')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.017470233609990657
#  RMSE on test set: 0.03274247563983211
# DTC ==== on normal scale
# RMSE on Training set: 1.5165049639139867
#  RMSE on test set: 2.9796579833180417
#
# DTS ==== on log scale
# RMSE on Training set: 0.022785571192664854
#  RMSE on test set: 0.04380526068791307
#
# DTS ==== on normal scale
# RMSE on Training set: 4.168943693612251
#  RMSE on test set: 8.720112273244403

# %%
LGB = lgb.LGBMRegressor()
poly = PolynomialFeatures(degree=2)
LGB = Pipeline([('poly', poly),('model',LGB)])

dtc_score, dts_score, dtc_model, dts_model, col = train_it(LGB,LGB, X_train[reg_var], y_train, plot = False)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='Base: LGBM')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.025238299123708858
#  RMSE on test set: 0.032840021080274416
# DTC ==== on normal scale
# RMSE on Training set: 2.230140524402743
#  RMSE on test set: 2.9444024869445053
#
# DTS ==== on log scale
# RMSE on Training set: 0.034578424514763076
#  RMSE on test set: 0.04384139715232654
#
# DTS ==== on normal scale
# RMSE on Training set: 6.494479465160966
#  RMSE on test set: 8.271315208175167

# %% [markdown]
# ## 2.5 Tuning on Algorithm Splitting between DTC and DTS <a class="anchor" id="2.5"></a>
#
# [back](#outline)<br>

# %%
'''DTC Algorithm'''
dtc_ml = lgb.LGBMRegressor()
dtc_poly = PolynomialFeatures(degree=2)
dtc_pipe = Pipeline([('poly', dtc_poly),('model',dtc_ml)])

'''DTC Algorithm'''
dts_ml = lgb.LGBMRegressor()
dts_poly = PolynomialFeatures(degree=2)

'Adding data Scaler on DTS Prediction'
dts_scaler = Normalizer()
dts_pipe = Pipeline([('poly', dts_poly),('scaler',dts_scaler ),('model',dts_ml)])

dtc_score, dts_score, dtc_model, dts_model, col = train_it(dtc_pipe,dts_pipe, X_train[reg_var], y_train, plot=True)
score_summary_append(dtc_score, dts_score, dtc_model, dts_model, col, comment='DTC DTS split: LGBM')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.025238299123708858
#  RMSE on test set: 0.032840021080274416
# DTC ==== on normal scale
# RMSE on Training set: 2.230140524402743
#  RMSE on test set: 2.9444024869445053
#
# DTS ==== on log scale
# RMSE on Training set: 0.03589987038875395
#  RMSE on test set: 0.048475903383162385
#
# DTS ==== on normal scale
# RMSE on Training set: 7.068474644907761
#  RMSE on test set: 10.17998856915463

# %% [markdown]
# ## 2.6 Tuning on Algorithm Splitting between DTC and DTS, with Engineered Features <a class="anchor" id="2.6"></a>
#
# [back](#outline)<br>

# %%
reg_var = ['ZDEN_log', 
           'CNC_log', 
           'CAL_log', 
           'HRD_log', 
           'HRM_log', 
           'GR_log', 
           'PE_log', 
           'litho_ord_log', ]

dtc_score, dts_score, dtc_model_2, dts_model_2, col =  train_it(dtc_pipe,dts_pipe, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_model_2, dts_model_2, col, comment='DTC DTS split: LGBM, less feature')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.026496279940625152
#  RMSE on test set: 0.0331477287745802
# DTC ==== on normal scale
# RMSE on Training set: 2.346451037561539
#  RMSE on test set: 2.972248223885372
#
# DTS ==== on log scale
# RMSE on Training set: 0.03835118634909902
#  RMSE on test set: 0.05070801945820347
#
# DTS ==== on normal scale
# RMSE on Training set: 7.363383868522165
#  RMSE on test set: 9.966789607893094

# %% [markdown]
# #### Submitted DTS Prediction

# %%
pred = pd.DataFrame()
pred['DTS'] = np.expm1(dts_model_2.predict(test_well[reg_var]))

# %% [markdown]
# # 3 2nd Group Feature Engineering: Petrophysical Analysis <a class="anchor" id="3"></a>
#
# [back](#outline)<br>

# %%
def PHID_calc(rhob, rhoma, rhofl):
    phid = (rhoma - rhofl)/(rhob - rhofl)
    return phid

def PHIT_calc(phin, phid):
    phit = (phin + phid)/2
    if phit >0.00001:
        return phit
    else:
        return 0.00001

def PHIE_calc(phit, vsh, phish):
    phie = phit - (vsh*phish)
    if phie >0.00001:
        return phie
    else:
        return 0.00001

def SW_calc(phie,rt, rw, a=1, m=2, n=2, ):
    sw = np.power((a*rw) / (rt* np.power(phie,m)), 1/n)
    if sw>1:
        return 1
    elif sw<0:
        return 0.00001
    else:
        return sw

def RHOMA_calc(NPHI, RHOB, GR, p90):

    if math.isnan(NPHI) or math.isnan(RHOB) or math.isnan(GR):
        return np.nan
    elif GR >= p90:
        return 2.7
    else:
        sst_line_start = (-0.02, 2.65)
        sst_line_end = (0.35, 2)

        lst_line_start = (0, 2.71)
        lst_line_end = (0.4, 2)

        dol_line_start = (0.02, 2.87)
        dol_line_end = (0.43, 2.14)

        dist_to_sst = dist_2d(sst_line_start, sst_line_end, (NPHI, RHOB))
        dist_to_lst = dist_2d(lst_line_start, lst_line_end, (NPHI, RHOB))
        dist_to_dol = dist_2d(dol_line_start, dol_line_end, (NPHI, RHOB))
        
        if dist_to_sst < dist_to_lst and dist_to_sst < dist_to_dol:
            return 2.56
        elif dist_to_lst < dist_to_sst and dist_to_lst < dist_to_dol:
            return 2.71
        elif dist_to_dol < dist_to_sst and dist_to_dol < dist_to_lst:
            return 2.83
        else:
            return np.nan

# %% [markdown]
# ## 3.1 Petrophysical Parameter Picking and Calculation <a class="anchor" id="3.1"></a>
#
# [back](#outline)<br>

# %%
'''Parameter picking: Matrix Property'''
plt.figure(figsize=(8,6))
plt.scatter('CNC','ZDEN', data=train_well, alpha=0.1,
            c = 'GR', vmin = 0, vmax= 150)
plt.plot([1, 0],[1, 2.71], label = 'Limestone Line', c='teal')
plt.plot([1,0.4, 0],[1, 2.7, 3.7], label = 'Shale Line', c='green')
plt.scatter([0],[3.7], c= 'red', label = 'Dry shale point')
plt.scatter([0.4],[2.7], c= 'black', label = 'Wet shale shale point')

plt.legend()
plt.ylim(4,1)
plt.xlim(0,1)
plt.colorbar()

# %% [raw]
# '''
# Parameter for Porosity calculation
# Vhale = GR_NDI (Adaptive GR Normalization)
#
# Rhofl = 1.1 (assuming all interval consist saline water)
#
# Rhoma = (depends on lithology)
# Rhoma Sand = 2.65
# Rhoma Limestone = 2.71
# Rhoma Dolomite = 2.87
# Rhoma Shale = 2.7 (according to Wetshale Point in ND plot)
#
# Nphi Shale = 0.4 (according to Wetshale Point in ND plot)
# '''

# %%
train_well['rhoma'] = train_well.apply(lambda df: RHOMA_calc(NPHI = df.CNC, RHOB = df.ZDEN, GR = df.GR, p90 = 90), axis = 1)
train_well['phid'] = train_well.apply(lambda df: PHID_calc(df.ZDEN, df.rhoma, rhofl=1.1), axis = 1)
train_well['phin'] = train_well['CNC']
train_well['phit'] = train_well.apply(lambda df: PHIT_calc(df.phid, df.phin), axis = 1)
train_well['phie'] = train_well.apply(lambda df: PHIE_calc(df.phit, df.GR_NDI, 0.4), axis = 1)

test_well['rhoma'] = test_well.apply(lambda df: RHOMA_calc(NPHI = df.CNC, RHOB = df.ZDEN, GR = df.GR, p90 = 90), axis = 1)
test_well['phid'] = test_well.apply(lambda df: PHID_calc(df.ZDEN, df.rhoma, rhofl=1.1), axis = 1)
test_well['phin'] = test_well['CNC']
test_well['phit'] = test_well.apply(lambda df: PHIT_calc(df.phid, df.phin), axis = 1)
test_well['phie'] = test_well.apply(lambda df: PHIE_calc(df.phit, df.GR_NDI, 0.4), axis = 1)

# %%
'''Parameter picking: Pickett Plot'''

plt.figure(figsize=(8,6))
plt.scatter('HRD','phie', data=train_well[train_well.GR_NDI <=0.3], c='GR_log', alpha=0.2)

plt.plot([0.01, 1000], [1,1], 
         c='black', alpha=0.5, linestyle = '--', linewidth=1)
plt.plot([0.02,0.02], [0.1, 1.5], 
         c='black', alpha=0.5, linestyle = '--', linewidth=1)

plt.plot([10, 0.02],[0.42,1], c = 'red', 
         linestyle = '--', linewidth=2, label='Pickett Plot line')

plt.scatter(0.02,1, c='blue', label = 'water point')

plt.ylim(0.3,1.5)
plt.xlim(0.01,100)

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

plt.xlabel('HRD')
plt.ylabel('PHIE')
plt.colorbar()
plt.legend()

# %% [raw]
# '''
# Parameter for Sw calculation
# Rw  = 0.02
# a = 1
# m = 2
# n = 2
# '''

# %%
train_well['sw'] = train_well.apply(lambda df: SW_calc(df.phie,df.HRD, rw=0.02, a=1, m=2, n=2, ), axis = 1)
test_well['sw'] = test_well.apply(lambda df: SW_calc(df.phie,df.HRD, rw=0.02, a=1, m=2, n=2, ), axis = 1)

# %% [markdown]
# ### Log Conversion

# %%
train_well['phid_log'] =np.log1p( train_well['phid'])
train_well['phin_log'] = np.log1p(train_well['phin'] )
train_well['phit_log'] = np.log1p(train_well['phit'])
train_well['phie_log'] = np.log1p(train_well['phie'])
train_well['sw_log'] = np.log1p(train_well['sw'])
# train_well['phie'] = train_well.apply(lambda df: PHIE_calc(df.phiE, df.GR_NDI, 0.4), axis = 1)

test_well['phid_log'] =np.log1p( test_well['phid'])
test_well['phin_log'] = np.log1p(test_well['phin'] )
test_well['phit_log'] = np.log1p(test_well['phit'])
test_well['phie_log'] = np.log1p(test_well['phie'])
test_well['sw_log'] = np.log1p(test_well['sw'])
# Out:
# c:\users\user\miniconda3\envs\learning\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### More Features (Ratio Features)

# %%
train_well['GR_NPHI'] = np.log1p(train_well['GR'] / train_well['CNC'])
train_well['GR_RHOB'] = np.log1p(train_well['GR'] / train_well['ZDEN'])
train_well['NPHI_RHOB'] = np.log1p(train_well['CNC'] / train_well['ZDEN'])
train_well['NPHI_RT'] = np.log1p(train_well['CNC'] / train_well['HRD'])
train_well['RHOB_RT'] = np.log1p(train_well['ZDEN'] / train_well['HRD'])

test_well['GR_NPHI'] = np.log1p(test_well['GR'] / test_well['CNC'])
test_well['GR_RHOB'] = np.log1p(test_well['GR'] / test_well['ZDEN'])
test_well['NPHI_RHOB'] = np.log1p(test_well['CNC'] / test_well['ZDEN'])
test_well['NPHI_RT'] = np.log1p(test_well['CNC'] / test_well['HRD'])
test_well['RHOB_RT'] = np.log1p(test_well['ZDEN'] / test_well['HRD'])

# %% [markdown]
# ## 3.2 Train Val Splitting <a class="anchor" id="3.2"></a>
#
# [back](#outline)<br>
#
# Due to new feature addition to the original train dataset, we need to redo Train-Val Split.

# %%
X_train, X_val, y_train, y_val = train_test_split(train_well.dropna().drop(['DTC', 'DTS', 'DTC_log', 'DTS_log'], axis = 1), 
                                                  train_well.dropna()[['DTC', 'DTS', 'DTC_log', 'DTS_log']], 
                                                  test_size = 0.2, 
                                                  random_state = 123)

# %% [markdown]
# ## 3.3 Running With Petrophysical Analysis as Features <a class="anchor" id="3.3"></a>
#
# [back](#outline)<br>

# %%
reg_var = ['ZDEN_log', 
           'CNC_log', 
           'CAL_log', 
           'HRD_log', 
           'HRM_log', 
           'GR_NDI', 
           'PE_log', 
           
           'litho_ord_log',
            'phit_log', 
            'phie_log',
            'sw_log']

# %%
'''DTC Algorithm'''
dtc_ml = lgb.LGBMRegressor()
dtc_poly = PolynomialFeatures(degree=2)
dtc_pipe = Pipeline([('poly', dtc_poly),('model',dtc_ml)])

'''DTC Algorithm'''
dts_ml = lgb.LGBMRegressor()
dts_poly = PolynomialFeatures(degree=2)
dts_scaler = Normalizer()
# dts_pipe = Pipeline([('poly', dts_poly),('model',dts_ml)])

dts_pipe = Pipeline([('poly', dts_poly),('scaler',dts_scaler ),('model',dts_ml)])

dtc_score, dts_score, dtc_lbgm_split_fe, dts_lbgm_split_fe, col =  train_it(dtc_pipe,dts_pipe, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_lbgm_split_fe, dts_lbgm_split_fe, col, comment='DTC DTS split + Petrophysic: LGBM')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.02763235652178435
#  RMSE on test set: 0.03480747821451245
# DTC ==== on normal scale
# RMSE on Training set: 2.4296750570119254
#  RMSE on test set: 3.082746821163782
#
# DTS ==== on log scale
# RMSE on Training set: 0.03808436240642548
#  RMSE on test set: 0.04778573788872578
#
# DTS ==== on normal scale
# RMSE on Training set: 7.154932358168705
#  RMSE on test set: 9.229026562294278

# %%
reg_var = ['GR_NPHI', 'GR_RHOB', 'NPHI_RHOB',
           'NPHI_RT', 'RHOB_RT',
           
           'ZDEN_log', 
           'CNC_log', 
           'CAL_log', 
           'HRD_log', 
           'HRM_log', 
           'GR_NDI', 
           'PE_log', 
           
           'litho_ord_log',
            'phit_log', 
            'phie_log',
            'sw_log']

# %%
'''DTC Algorithm'''
dtc_ml = lgb.LGBMRegressor()
dtc_poly = PolynomialFeatures(degree=2)
dtc_pipe = Pipeline([('poly', dtc_poly),('model',dtc_ml)])

'''DTC Algorithm'''
dts_ml = lgb.LGBMRegressor()
dts_poly = PolynomialFeatures(degree=2)
dts_scaler = Normalizer()
# dts_pipe = Pipeline([('poly', dts_poly),('model',dts_ml)])

dts_pipe = Pipeline([('poly', dts_poly),('scaler',dts_scaler ),('model',dts_ml)])

dtc_score, dts_score, dtc_lbgm_split_fe, dts_lbgm_split_fe, col =  train_it(dtc_pipe,dts_pipe, X_train[reg_var], y_train)
score_summary_append(dtc_score, dts_score, dtc_lbgm_split_fe, dts_lbgm_split_fe, col, comment='DTC DTS split + Petrophysic + ratio: LGBM')
# Out:
# DTC ==== on log scale
# RMSE on Training set: 0.024240536291682085
#  RMSE on test set: 0.031834144902574614
# DTC ==== on normal scale
# RMSE on Training set: 2.156495413572456
#  RMSE on test set: 2.868093310513045
#
# DTS ==== on log scale
# RMSE on Training set: 0.033977032462414035
#  RMSE on test set: 0.04660813685200878
#
# DTS ==== on normal scale
# RMSE on Training set: 6.59744982411947
#  RMSE on test set: 9.151456424300637

# %% [markdown]
# # 4 Model Stacking <a class="anchor" id="4"></a>
#
# [back](#outline)<br>

# %%
'''We reckon ther is one missing value, 
   thus we need to Fill the missing value on Test Dataset'''

test_well['GR_NDI'].fillna(value=test_well['GR_NDI'].mean(), inplace=True)

# %% [raw]
# Idea:
# Uses DTC DTS output from several model, and use it as input for DTC DTS Prediction
#
#
#   Level 1 Predict
#   Model                       Output Name
#   =======================================
# - RandomForestRegressor     -> DTC_rf
# - GradientBoostingRegressor -> DTC_gbr
# - AdaBoostRegressor         -> DTC_ada
# - ExtraTreesRegressor       -> DTC_etr
# - Lasso                     -> DTC_lasso
# - Ridge                     -> DTC_ridge
# - LinearRegression          -> DTC_lr
#
# Level 2 Predict
# input from lvl 1 pred             Model         Output
# ====================================================================
# DTC_rf, DTC_gbr, DTC_ada,
# DTC_etr, DTC_lasso,       =====> XGBOOST  ===> DTC_pred
# DTC_ridge, DTC_lr

# %%
def train_stack_lvl1(model, reg_var, target, name):
    
    mla = model
    poly = PolynomialFeatures(degree=2)
    scaler = Normalizer()
    
    if target == 'DTS':
        pipe = Pipeline([('poly', poly),('scaler',scaler ),('model',mla)])    
    else:
        pipe = Pipeline([('poly', poly),('model',mla)])    

    pipe.fit(X_train[reg_var], y_train[target+'_log'] )
    
    print ('====== ',target, ' Lvl 1 Prediction')
    print ('====== Using MLA: ', name)
    print('RMSE Train: ',np.sqrt(mean_squared_error(np.expm1(pipe.predict(X_train[reg_var])), y_train[target])))
    print('RMSE val: ', np.sqrt(mean_squared_error(np.expm1(pipe.predict(X_val[reg_var])), y_val[target])))
    print('\n')
    
    train_pred = np.expm1(pipe.predict(X_train[reg_var]))

    output_pred = np.expm1(pipe.predict(test_well[reg_var]))

    val_pred = np.expm1(pipe.predict(X_val[reg_var]))
    
    return str(pipe), train_pred, val_pred, output_pred

def train_stack_lvl2(model_dict, reg_var):

    '''Modelling fot DTC'''

    to_train = 'DTC'

    pred_train = pd.DataFrame()
    pred_val = pd.DataFrame()
    pred_out_dtc = pd.DataFrame()

    for i in range(len(model_dict['name'])):
        model = model_dict['model'][i]
        name  = model_dict['name'][i]+'_'+to_train

        _, \
        pred_train[name], \
        pred_val[name], \
        pred_out_dtc[name] = train_stack_lvl1(model, reg_var, to_train, name)

    dtc_model = lgb.LGBMRegressor(random_state=123)
    reg_lv1 = list(pred_train.columns)
    dtc_model.fit(pred_train[reg_lv1], y_train[to_train])

    dtc_score_train = np.sqrt(mean_squared_error(dtc_model.predict(pred_train[reg_lv1]), y_train[to_train]))
    dtc_score_val = np.sqrt(mean_squared_error(dtc_model.predict(pred_val[reg_lv1]), y_val[to_train]))
    
    
    pred_train_dtc = pred_train
    pred_val_dtc = pred_val

    print ('======  DTC Lvl 2 Prediction')
    print ('feature used: ', reg_lv1)
    print ('train RMSE: ', dtc_score_train)
    print ('val RMSE: ', dtc_score_val)
    print ('================================\n\n')

    dtc_score = [dtc_score_train, dtc_score_val]

    '''Modelling fot DTS'''

    to_train = 'DTS'
    
    pred_train = pd.DataFrame()
    pred_val = pd.DataFrame()
    pred_out_dts = pd.DataFrame()

    for i in range(len(model_dict['name'])):
        model = model_dict['model'][i]
        name  = model_dict['name'][i]+'_'+to_train

        _, \
        pred_train[name], \
        pred_val[name], \
        pred_out_dts[name] = train_stack_lvl1(model, reg_var, to_train, name)

    dts_model = lgb.LGBMRegressor(random_state=123)
    reg_lv1 = list(pred_train.columns)
    dts_model.fit(pred_train[reg_lv1], y_train[to_train])

    dts_score_train = np.sqrt(mean_squared_error(dts_model.predict(pred_train[reg_lv1]), y_train[to_train]))
    dts_score_val = np.sqrt(mean_squared_error(dts_model.predict(pred_val[reg_lv1]), y_val[to_train]))
    
    pred_train_dts= pred_train
    pred_val_dts= pred_val
    
    print ('======  DTS Lvl 2 Prediction')
    print ('feature used: ', reg_lv1)
    print ('train RMSE: ',dts_score_train)
    print ('val RMSE: ',dts_score_val)
    print ('================================')
    print ('================================\n\n\n')

    dts_score = [dts_score_train, dts_score_val]


    return  dtc_model, dts_model, \
            pred_train_dtc, pred_val_dtc, pred_out_dtc, \
            pred_train_dts, pred_val_dts, pred_out_dts,\
            dtc_score, dts_score

# %% [markdown]
# ## 4.1 Model Stacking Training and Scoring <a class="anchor" id="4.1"></a>
#
# [back](#outline)<br>

# %%
reg_var = ['ZDEN_log', 
           'CNC_log', 
           'CAL_log', 
           'HRD_log', 
           'HRM_log', 
           'GR_NDI', 
           'PE_log', 
           'litho_ord_log']

model_dict    = {'name' : [ 'LGBM', 'RF', 'GBR','ADA','EXTRA', 'LASSO', 'RIDGE', 'LR',],
                 'model': [lgb.LGBMRegressor(random_state=123),
                           RandomForestRegressor(random_state=123),
                           GradientBoostingRegressor(random_state=123),
                           AdaBoostRegressor(random_state=123),
                           ExtraTreesRegressor(random_state=123),
                           Lasso(random_state=123),
                           Ridge(random_state=123),
                           LinearRegression(),]}


dtc_model, dts_model,  \
pred_train_dtc, pred_val_dtc, pred_out_dtc, \
pred_train_dts, pred_val_dts, pred_out_dts,\
dtc_score, dts_score = train_stack_lvl2(model_dict,reg_var)

score_summary_append(dtc_score, dts_score, 
                     dtc_model, dts_model, 
                     reg_var, comment='Model Stacking: Basic log')
# Out:
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  LGBM_DTC
# RMSE Train:  2.506908797403549
# RMSE val:  3.0643041994813824
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  RF_DTC
# RMSE Train:  1.0625178821516401
# RMSE val:  2.8224535917320104
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  GBR_DTC
# RMSE Train:  3.4093059790254445
# RMSE val:  3.712918266947588
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  ADA_DTC
# RMSE Train:  5.18412058896002
# RMSE val:  5.321310567485029
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  EXTRA_DTC
# RMSE Train:  0.003813467585406107
# RMSE val:  2.556275319806706
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  LASSO_DTC
# RMSE Train:  22.313225935699407
# RMSE val:  22.586494797454826
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  RIDGE_DTC
# RMSE Train:  4.5002844117235155
# RMSE val:  4.515425680084203
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  LR_DTC
# RMSE Train:  4.2461856916658105
# RMSE val:  4.282305757910561
#
#
# ======  DTC Lvl 2 Prediction
# feature used:  ['LGBM_DTC', 'RF_DTC', 'GBR_DTC', 'ADA_DTC', 'EXTRA_DTC', 'LASSO_DTC', 'RIDGE_DTC', 'LR_DTC']
# train RMSE:  0.18500176671678156
# val RMSE:  2.5582516481272086
# ================================
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  LGBM_DTS
# RMSE Train:  7.439985620096641
# RMSE val:  9.107865413060043
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  RF_DTS
# RMSE Train:  3.162772562701476
# RMSE val:  8.089336213704687
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  GBR_DTS
# RMSE Train:  10.292849812901734
# RMSE val:  11.675049356425033
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  ADA_DTS
# RMSE Train:  14.111946923271748
# RMSE val:  14.916504887457426
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  EXTRA_DTS
# RMSE Train:  0.007180285975244053
# RMSE val:  7.72501158936279
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  LASSO_DTS
# RMSE Train:  80.95475634922171
# RMSE val:  82.35636104342669
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  RIDGE_DTS
# RMSE Train:  24.351093979445956
# RMSE val:  28.317506169047867
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  LR_DTS
# RMSE Train:  13.361648078346693
# RMSE val:  13.540658431723735
#
#
# ======  DTS Lvl 2 Prediction
# feature used:  ['LGBM_DTS', 'RF_DTS', 'GBR_DTS', 'ADA_DTS', 'EXTRA_DTS', 'LASSO_DTS', 'RIDGE_DTS', 'LR_DTS']
# train RMSE:  0.7999964618267448
# val RMSE:  7.639333661190433
# ================================
# ================================

# %% [markdown]
# #### Submitted DTC prediction

# %%
reg_var = ['ZDEN_log', 
           'CNC_log', 
           'CAL_log', 
           'HRD_log', 
           'HRM_log', 
           'GR_NDI', 
           'PE_log', 
           'litho_ord_log',
           
           'phit_log', 
           'phie_log',
           'sw_log']

model_dict    = {'name' : [ 'LGBM', 'RF', 'GBR','ADA','EXTRA', 'LASSO', 'RIDGE', 'LR',],
                 'model': [lgb.LGBMRegressor(random_state=123),
                           RandomForestRegressor(random_state=123),
                           GradientBoostingRegressor(random_state=123),
                           AdaBoostRegressor(random_state=123),
                           ExtraTreesRegressor(random_state=123),
                           Lasso(random_state=123),
                           Ridge(random_state=123),
                           LinearRegression(),]}


dtc_model, dts_model,  \
pred_train_dtc, pred_val_dtc, pred_out_dtc, \
pred_train_dts, pred_val_dts, pred_out_dts,\
dtc_score, dts_score = train_stack_lvl2(model_dict,reg_var)

score_summary_append(dtc_score, dts_score, 
                     dtc_model, dts_model, 
                     reg_var, comment='Model Stacking: Basic log + Petrophysic')
# Out:
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  LGBM_DTC
# RMSE Train:  2.4296750570119254
# RMSE val:  3.082746821163782
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  RF_DTC
# RMSE Train:  1.0839028924060043
# RMSE val:  2.898515150313698
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  GBR_DTC
# RMSE Train:  3.362881428570013
# RMSE val:  3.6748020953102607
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  ADA_DTC
# RMSE Train:  4.891231867399978
# RMSE val:  5.0348116072445634
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  EXTRA_DTC
# RMSE Train:  0.003886500510681296
# RMSE val:  2.682157034198561
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  LASSO_DTC
# RMSE Train:  22.313225935699407
# RMSE val:  22.586494797454826
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  RIDGE_DTC
# RMSE Train:  4.3723543665239815
# RMSE val:  4.431844645195055
#
#
# ======  DTC  Lvl 1 Prediction
# ====== Using MLA:  LR_DTC
# RMSE Train:  4.0983220746855995
# RMSE val:  4.096081950901622
#
#
# ======  DTC Lvl 2 Prediction
# feature used:  ['LGBM_DTC', 'RF_DTC', 'GBR_DTC', 'ADA_DTC', 'EXTRA_DTC', 'LASSO_DTC', 'RIDGE_DTC', 'LR_DTC']
# train RMSE:  0.1820465459880244
# val RMSE:  2.6960478237462002
# ================================
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  LGBM_DTS
# RMSE Train:  7.154932358168705
# RMSE val:  9.229026562294278
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  RF_DTS
# RMSE Train:  3.2045994532766575
# RMSE val:  7.799605831318502
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  GBR_DTS
# RMSE Train:  10.132795387496717
# RMSE val:  11.779940717897421
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  ADA_DTS
# RMSE Train:  14.177041745326886
# RMSE val:  14.78626132733418
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  EXTRA_DTS
# RMSE Train:  0.007488174214345263
# RMSE val:  7.708780006624644
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  LASSO_DTS
# RMSE Train:  80.95475634922171
# RMSE val:  82.35636104342669
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  RIDGE_DTS
# RMSE Train:  25.027320145099196
# RMSE val:  28.88708536570455
#
#
# ======  DTS  Lvl 1 Prediction
# ====== Using MLA:  LR_DTS
# RMSE Train:  12.889943215857508
# RMSE val:  13.340862313070946
#
#
# ======  DTS Lvl 2 Prediction
# feature used:  ['LGBM_DTS', 'RF_DTS', 'GBR_DTS', 'ADA_DTS', 'EXTRA_DTS', 'LASSO_DTS', 'RIDGE_DTS', 'LR_DTS']
# train RMSE:  0.7868944742662565
# val RMSE:  7.641149592827243
# ================================
# ================================

# %%
pred['DTC'] = dtc_model.predict(pred_out_dtc)

# %% [markdown]
# ## DTC DTS Final Prediction

# %%
pred[['DTC', 'DTS']]
# Out:
#               DTC         DTS
# 0      107.324564  283.496451
# 1      108.804671  283.090719
# 2      108.815930  283.021539
# 3      109.840966  284.144845
# 4      108.852788  286.900915
# ...           ...         ...
# 11083   83.567881  146.350092
# 11084   83.567881  146.350092
# 11085   82.349650  146.084669
# 11086   82.356702  145.592204
# 11087   83.259219  145.025449
#
# [11088 rows x 2 columns]

# %%
pred[['DTC','DTS']].to_csv('final submission.csv')
